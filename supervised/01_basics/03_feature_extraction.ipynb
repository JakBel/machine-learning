# %% [markdown]
# <a href="https://colab.research.google.com/github/JakBel/machine-learning/blob/main/supervised/01_basics/03_feature_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn

sklearn.__version__
# Out:
# '1.0.2'

# %% [markdown]
# **Załadowanie danych**

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetches stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df_raw = fetch_financial_data()
df_raw.head()
# Out:
#                Open       High        Low    Close   Volume
# Date
# 2022-05-23  2169.22  2176.3750  2079.0000  2151.14  5329385
# 2022-05-20  2191.37  2197.9599  2100.1868  2151.82  4975032
# 2022-05-19  2125.61  2200.6800  2123.8581  2146.38  4407127
# 2022-05-18  2228.79  2257.0600  2124.9750  2142.25  5418959
# 2022-05-17  2265.50  2316.0000  2225.5300  2307.37  3822387

# %% [markdown]
# **Utworzenie kopii**

# %%
df = df_raw.copy()
df = df[:5]
df
# Out:
#                Open       High        Low    Close   Volume
# Date
# 2022-05-23  2169.22  2176.3750  2079.0000  2151.14  5329385
# 2022-05-20  2191.37  2197.9599  2100.1868  2151.82  4975032
# 2022-05-19  2125.61  2200.6800  2123.8581  2146.38  4407127
# 2022-05-18  2228.79  2257.0600  2124.9750  2142.25  5418959
# 2022-05-17  2265.50  2316.0000  2225.5300  2307.37  3822387

# %% [markdown]
# **Generowanie nowych zmiennych**

# %%
df.index.month
# Out:
# Int64Index([5, 5, 5, 5, 5], dtype='int64', name='Date')

# %%
df['day'] = df.index.day
df['month'] = df.index.month
df['year'] = df.index.year
df
# Out:
#                Open       High        Low    Close   Volume  day  month  year
# Date
# 2022-05-23  2169.22  2176.3750  2079.0000  2151.14  5329385   23      5  2022
# 2022-05-20  2191.37  2197.9599  2100.1868  2151.82  4975032   20      5  2022
# 2022-05-19  2125.61  2200.6800  2123.8581  2146.38  4407127   19      5  2022
# 2022-05-18  2228.79  2257.0600  2124.9750  2142.25  5418959   18      5  2022
# 2022-05-17  2265.50  2316.0000  2225.5300  2307.37  3822387   17      5  2022

# %% [markdown]
# **Dyskretyzacja zmiennej ciągłej**

# %%
df = pd.DataFrame(data={'height': [175., 178.5, 185., 191., 184.5, 183., 168.]})
df
# Out:
#    height
# 0   175.0
# 1   178.5
# 2   185.0
# 3   191.0
# 4   184.5
# 5   183.0
# 6   168.0

# %%
df['height_cat'] = pd.cut(x=df.height, bins=3) #Tworzy odpowiednie przedziały
df
# Out:
#    height          height_cat
# 0   175.0  (167.977, 175.667]
# 1   178.5  (175.667, 183.333]
# 2   185.0    (183.333, 191.0]
# 3   191.0    (183.333, 191.0]
# 4   184.5    (183.333, 191.0]
# 5   183.0  (175.667, 183.333]
# 6   168.0  (167.977, 175.667]

# %%
df['height_cat'] = pd.cut(x=df.height, bins=(160, 175, 180, 195))
df
# Out:
#    height  height_cat
# 0   175.0  (160, 175]
# 1   178.5  (175, 180]
# 2   185.0  (180, 195]
# 3   191.0  (180, 195]
# 4   184.5  (180, 195]
# 5   183.0  (180, 195]
# 6   168.0  (160, 175]

# %%
df['height_cat'] = pd.cut(x=df.height, bins=(160, 175, 180, 195), labels=['small', 'medium', 'high'])
df
# Out:
#    height height_cat
# 0   175.0      small
# 1   178.5     medium
# 2   185.0       high
# 3   191.0       high
# 4   184.5       high
# 5   183.0       high
# 6   168.0      small

# %%
pd.get_dummies(df, drop_first=True, prefix='height')
# Out:
#    height  height_medium  height_high
# 0   175.0              0            0
# 1   178.5              1            0
# 2   185.0              0            1
# 3   191.0              0            1
# 4   184.5              0            1
# 5   183.0              0            1
# 6   168.0              0            0

# %% [markdown]
# **Ekstrakcja cech**

# %%
df = pd.DataFrame(data={'lang': [['PL', 'ENG'], ['GER', 'ENG', 'PL', 'FRA'], ['RUS']]})
df
# Out:
#                   lang
# 0            [PL, ENG]
# 1  [GER, ENG, PL, FRA]
# 2                [RUS]

# %%
df['lang_number'] = df['lang'].apply(len)
df
# Out:
#                   lang  lang_number
# 0            [PL, ENG]            2
# 1  [GER, ENG, PL, FRA]            4
# 2                [RUS]            1

# %%
df['PL_flag'] = df['lang'].apply(lambda x: 1 if 'PL' in x else 0)
df
# Out:
#                   lang  lang_number  PL_flag
# 0            [PL, ENG]            2        1
# 1  [GER, ENG, PL, FRA]            4        1
# 2                [RUS]            1        0

# %%
df = pd.DataFrame(data={'website': ['wp.pl', 'onet.pl', 'google.com']})
df
# Out:
#       website
# 0       wp.pl
# 1     onet.pl
# 2  google.com

# %%
df.website.str.split('.', expand=True)
# Out:
#         0    1
# 0      wp   pl
# 1    onet   pl
# 2  google  com

# %%
new = df.website.str.split('.', expand=True)
df['portal'] = new[0]
df['extension'] = new[1]
df
# Out:
#       website  portal extension
# 0       wp.pl      wp        pl
# 1     onet.pl    onet        pl
# 2  google.com  google       com
